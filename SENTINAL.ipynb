# %%
import os

# %%
os.makedirs('data/threat', exist_ok=True)
os.makedirs('data/normal', exist_ok=True)
print("Folders created ✅")
print("Current working directory:", os.getcwd())
# Out:
# Folders created ✅
# Current working directory: C:\Users\pandureddy

# %%
import cv2, os
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# C:\Users\PANDUR~1\AppData\Local\Temp/ipykernel_14068/2043060115.py in <module>
# ----> 1 import cv2, os
#
# ModuleNotFoundError: No module named 'cv2'

# %%
# !pip install opencv-python
# Out:
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.20.3
#     Uninstalling numpy-1.20.3:
#       Successfully uninstalled numpy-1.20.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# daal4py 2021.3.0 requires daal==2021.2.3, which is not installed.
# scipy 1.7.1 requires numpy<1.23.0,>=1.16.5, but you have numpy 2.0.2 which is incompatible.
# numba 0.54.1 requires numpy<1.21,>=1.17, but you have numpy 2.0.2 which is incompatible.
# ...

# %%
import cv2, os

# %%
VIDEO_PATH = r'C:\Users\pandureddy\OneDrive\Desktop\New folder'

# %%
# !pip install numpy==1.22.4
# Out:
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\pandureddy\\anaconda3\\Lib\\site-packages\\~umpy.libs\\libscipy_openblas64_-caad452230ae4ddb57899b8b3a33c55c.dll'
# Consider using the `--user` option or check the permissions.

# %%
import cv2
import numpy as np

print("OpenCV version:", cv2.__version__)
print("NumPy version:", np.__version__)
# Out:
# OpenCV version: 4.13.0
# NumPy version: 2.0.2

# %%
import cv2, os

# %%
VIDEO_PATH = r'C:\Users\pandureddy\OneDrive\Desktop\New folder'

# %%
os.makedirs('data/normal', exist_ok=True)

# %%
cap = cv2.VideoCapture(VIDEO_PATH)
if not cap.isOpened():
    print("❌ Cannot open video — check the path above!")
else:
    saved = 0
    count = 0
    while saved < 100:               
        ret, frame = cap.read()
        if not ret:
            break
        if count % 15 == 0:          
            cv2.imwrite(f'data/normal/normal_{count:05d}.jpg', frame)
            saved += 1
        count += 1
    cap.release()
    print(f"✅ Saved {saved} normal frames to data/normal/")
# Out:
# ❌ Cannot open video — check the path above!

# %%
INPUT_VIDEO_PATH  =r'C:\Users\pandureddy\OneDrive\Desktop\New folder\video.mp4'

# %%
OUTPUT_VIDEO_PATH = 'output_threat_detected.mp4'

# %%
import glob

# %%
threat_imgs = glob.glob('data/threat/*.*')
normal_imgs = glob.glob('data/normal/*.*')
print(f"Threat images : {len(threat_imgs)}")
print(f"Normal images : {len(normal_imgs)}")
print(f"Video exists  : {os.path.exists(INPUT_VIDEO_PATH)}")
# Out:
# Threat images : 0
# Normal images : 0
# Video exists  : True

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\pandureddy

# %%
import cv2

cap = cv2.VideoCapture(INPUT_VIDEO_PATH)

saved = 0
count = 0

while saved < 100:
    ret, frame = cap.read()
    if not ret:
        break

    if count % 15 == 0:
        cv2.imwrite(f"data/normal/normal_{count}.jpg", frame)
        saved += 1

    count += 1

cap.release()

print("Saved normal images:", saved)
# Out:
# Saved normal images: 0

# %%
import glob

print("Threat images :", len(glob.glob("data/threat/*")))
print("Normal images :", len(glob.glob("data/normal/*")))
# Out:
# Threat images : 0
# Normal images : 0

# %%
import os

print("Threat folder files:", os.listdir("data/threat"))
print("Normal folder files:", os.listdir("data/normal"))
# Out:
# Threat folder files: []
# Normal folder files: []

# %%
import cv2

cap = cv2.VideoCapture(INPUT_VIDEO_PATH)

saved = 0
count = 0

while saved < 100:
    ret, frame = cap.read()
    
    if not ret:
        break

    if count % 15 == 0:
        cv2.imwrite(f"data/normal/normal_{count}.jpg", frame)
        saved += 1

    count += 1

cap.release()

print("Normal images saved:", saved)
# Out:
# Normal images saved: 0

# %%
import os

print(os.path.exists(INPUT_VIDEO_PATH))
print(INPUT_VIDEO_PATH)
# Out:
# True
# C:\Users\pandureddy\OneDrive\Desktop\New folder

# %%
import cv2

cap = cv2.VideoCapture(INPUT_VIDEO_PATH)

print("Video opened:", cap.isOpened())

ret, frame = cap.read()
print("Frame read:", ret)

cap.release()
# Out:
# Video opened: True
# Frame read: True

# %%
import cv2
import os

os.makedirs("data/normal", exist_ok=True)

cap = cv2.VideoCapture(INPUT_VIDEO_PATH)

saved = 0
count = 0

while True:
    ret, frame = cap.read()
    if not ret:
        break

    if count % 15 == 0:
        cv2.imwrite(f"data/normal/normal_{saved}.jpg", frame)
        saved += 1

    count += 1

cap.release()

print("Normal images saved:", saved)
# Out:
# Normal images saved: 28

# %%
import glob
print("Normal images:", len(glob.glob("data/normal/*")))
# Out:
# Normal images: 28

# %%
threat_imgs = glob.glob('data/threat/*.*')
normal_imgs = glob.glob('data/normal/*.*')
print(f"Threat images : {len(threat_imgs)}")
print(f"Normal images : {len(normal_imgs)}")
print(f"Video exists  : {os.path.exists(INPUT_VIDEO_PATH)}")
# Out:
# Threat images : 0
# Normal images : 28
# Video exists  : True

# %%
import os

print(os.path.exists("data/threat"))
# Out:
# True

# %%
import os

print(os.listdir("data/threat"))
# Out:
# []

# %%
import glob

threat_imgs = glob.glob("data/threat/*")
normal_imgs = glob.glob("data/normal/*")

print("Threat images:", len(threat_imgs))
print("Normal images:", len(normal_imgs))
# Out:
# Threat images: 0
# Normal images: 28

# %%
import glob

print("Threat images:", len(glob.glob("data/threat/*")))
print("Normal images:", len(glob.glob("data/normal/*")))
# Out:
# Threat images: 0
# Normal images: 28

# %%
INPUT_VIDEO_PATH = "video.mp4"

# %%
import cv2

INPUT_VIDEO_PATH = "video.mp4"

cap = cv2.VideoCapture(INPUT_VIDEO_PATH)

print("Video opened:", cap.isOpened())

ret, frame = cap.read()
print("First frame read:", ret)

cap.release()
# Out:
# Video opened: False
# First frame read: False

# %%
import os
print(os.listdir())
# Out:
# [' atm_interface-Copy1.ipynb', ' atm_interface.ipynb', '-1.14-windows.xml', '.android', '.angular-config.json', '.antigravity', '.astropy', '.cache', '.conda', '.condarc', '.continuum', '.dist', '.eclipse', '.emulator_console_auth_token', '.gemini', '.gradle', '.ipynb_checkpoints', '.ipython', '.jupyter', '.m2', '.matplotlib', '.ms-ad', '.p2', '.spyder-py3', '.sts4', '.vscode', '3D Objects', 'anaconda3', 'AndroidStudioProjects', 'ansel', 'AppData', 'Application Data', 'battery-report.html', 'C PROGRAM', 'Contacts', 'Cookies', 'Creative Cloud Files', 'data', 'day one mca.ipynb', 'Documents', 'Downloads', 'eclipse', 'eclipse-workspace', 'Favorites', 'functions.ipynb', 'IntelGraphicsProfiles', 'Jedi', 'Links', 'list practice ..pandu.ipynb', 'list2 practice.ipynb', 'Local Settings', 'mishra.python.ipynb', 'Music', 'My Documents', 'NetHood', 'NTUSER.DAT', 'ntuser.dat.LOG1', 'ntuser.dat.LOG2', 'NTUSER.DAT{2ad838bb-efea-11ee-a54d-000d3a94eaa1}.TxR.0.regtrans-ms', 'NTUSER.DAT{2ad838bb-efea-1
# ...

# %%
import os
import shutil

os.makedirs("data/threat", exist_ok=True)

images = [
"WhatsApp Image 2026-03-08 at 7.00.04 PM.jpeg",
"WhatsApp Image 2026-03-08 at 7.00.04 PM (1).jpeg",
"WhatsApp Image 2026-03-08 at 7.00.05 PM.jpeg",
"WhatsApp Image 2026-03-08 at 7.00.05 PM (1).jpeg"
]

for img in images:
    shutil.move(img, "data/threat/"+img)

print("Images moved successfully ✅")
# Out:
# Images moved successfully ✅

# %%
import glob

print("Threat images:", len(glob.glob("data/threat/*")))
print("Normal images:", len(glob.glob("data/normal/*")))
# Out:
# Threat images: 4
# Normal images: 28

# %%
import glob

threat_imgs = glob.glob('data/threat/*.*')
normal_imgs = glob.glob('data/normal/*.*')
print(f"Threat images : {len(threat_imgs)}")
print(f"Normal images : {len(normal_imgs)}")
print(f"Video exists  : {os.path.exists(INPUT_VIDEO_PATH)}")
# Out:
# Threat images : 4
# Normal images : 28
# Video exists  : False

# %%
import glob

threat_imgs = glob.glob('data/threat/*.*')
normal_imgs = glob.glob('data/normal/*.*')
print(f"Threat images : {len(threat_imgs)}")
print(f"Normal images : {len(normal_imgs)}")
print(f"Video exists  : {os.path.exists(INPUT_VIDEO_PATH)}")
# Out:
# Threat images : 4
# Normal images : 28
# Video exists  : False

# %%
import os
print(os.listdir(r"C:\Users\pandureddy\OneDrive\Desktop\New folder"))
# Out:
# ['HOG.ipynb', 'video.mp4', 'WhatsApp Image 2026-03-08 at 7.00.04 PM (1).jpeg', 'WhatsApp Image 2026-03-08 at 7.00.04 PM.jpeg', 'WhatsApp Image 2026-03-08 at 7.00.05 PM (1).jpeg', 'WhatsApp Image 2026-03-08 at 7.00.05 PM.jpeg']

# %%
INPUT_VIDEO_PATH = "video.mp4"

# %%
import os

INPUT_VIDEO_PATH = "video.mp4"

print("Video exists:", os.path.exists(INPUT_VIDEO_PATH))
# Out:
# Video exists: False

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\pandureddy

# %%
import os

os.chdir(r"C:\Users\pandureddy\OneDrive\Desktop\New folder")

print("Current folder:", os.getcwd())
# Out:
# Current folder: C:\Users\pandureddy\OneDrive\Desktop\New folder

# %%
INPUT_VIDEO_PATH = "video.mp4"

# %%
import os
print("Video exists:", os.path.exists(INPUT_VIDEO_PATH))
# Out:
# Video exists: True

# %%
import glob

threat_imgs = glob.glob('data/threat/*.*')
normal_imgs = glob.glob('data/normal/*.*')
print(f"Threat images : {len(threat_imgs)}")
print(f"Normal images : {len(normal_imgs)}")
print(f"Video exists  : {os.path.exists(INPUT_VIDEO_PATH)}")
# Out:
# Threat images : 0
# Normal images : 0
# Video exists  : True

# %%
import cv2

cap = cv2.VideoCapture(INPUT_VIDEO_PATH)

print("Video opened:", cap.isOpened())

ret, frame = cap.read()
print("Frame read:", ret)

cap.release()
# Out:
# Video opened: True
# Frame read: True

# %%
import os
print(os.listdir())
# Out:
# ['HOG.ipynb', 'video.mp4', 'WhatsApp Image 2026-03-08 at 7.00.04 PM (1).jpeg', 'WhatsApp Image 2026-03-08 at 7.00.04 PM.jpeg', 'WhatsApp Image 2026-03-08 at 7.00.05 PM (1).jpeg', 'WhatsApp Image 2026-03-08 at 7.00.05 PM.jpeg']

# %%
import os

os.makedirs("data/threat", exist_ok=True)
os.makedirs("data/normal", exist_ok=True)

print("Folders created")
# Out:
# Folders created

# %%
import shutil
import os

images = [f for f in os.listdir() if f.endswith(".jpeg")]

for img in images:
    shutil.move(img, "data/threat/"+img)

print("Threat images moved ✅")
# Out:
# Threat images moved ✅

# %%
import cv2

cap = cv2.VideoCapture("video.mp4")

saved = 0
count = 0

while True:
    ret, frame = cap.read()
    if not ret:
        break

    if count % 15 == 0:
        cv2.imwrite(f"data/normal/normal_{saved}.jpg", frame)
        saved += 1

    count += 1

cap.release()

print("Normal images saved:", saved)
# Out:
# Normal images saved: 28

# %%
import glob, os

threat_imgs = glob.glob('data/threat/*.*')
normal_imgs = glob.glob('data/normal/*.*')

print("Threat images:", len(threat_imgs))
print("Normal images:", len(normal_imgs))
print("Video exists:", os.path.exists("video.mp4"))
# Out:
# Threat images: 4
# Normal images: 28
# Video exists: True

# %%
print(dir())
# Out:
# ['INPUT_VIDEO_PATH', 'In', 'OUTPUT_VIDEO_PATH', 'Out', 'VIDEO_PATH', '_', '__', '___', '__builtin__', '__builtins__', '__doc__', '__loader__', '__name__', '__package__', '__spec__', '_dh', '_exit_code', '_i', '_i1', '_i10', '_i11', '_i12', '_i13', '_i14', '_i15', '_i16', '_i17', '_i18', '_i19', '_i2', '_i20', '_i21', '_i22', '_i23', '_i24', '_i25', '_i26', '_i27', '_i28', '_i29', '_i3', '_i30', '_i31', '_i32', '_i33', '_i34', '_i35', '_i36', '_i37', '_i38', '_i39', '_i4', '_i40', '_i41', '_i42', '_i43', '_i44', '_i45', '_i46', '_i47', '_i48', '_i49', '_i5', '_i50', '_i51', '_i52', '_i53', '_i54', '_i55', '_i56', '_i57', '_i58', '_i6', '_i7', '_i8', '_i9', '_ih', '_ii', '_iii', '_oh', 'cap', 'count', 'cv2', 'exit', 'f', 'frame', 'get_ipython', 'glob', 'images', 'img', 'normal_imgs', 'np', 'os', 'pickle', 'quit', 'ret', 'saved', 'shutil', 'threat_imgs']
